# %% [markdown]
# # 🎉 Welcome to Google Colab!

# %% [markdown]
# Google Colab is your free, browser-based coding playground.
# No installs, no setup, just code and go.
#
# **🔑 Key benefits:**
#
# ✅ **No need to install anything.** No hassle.
# ✅ **Runs Python code directly.** Compatible with almost every lesson.
# ✅ **Uses a secure, temporary environment.** Safer for your computer.
# ✅ **Includes Gemini**, Google’s own AI assistant (like ChatGPT, but built into the editor!).
# ✅ **Easy to reset:** Close the tab and open it again. You’re back to a fresh start.

# %% [markdown]
# ---

# %% [markdown]
# # ⚠️ Google Colab: Things to Watch Out For

# %% [markdown]
# While Colab is a great place to start, here are a few limitations to keep in mind:
# * **⏳ It times out:** Colab disconnects if you’re idle too long (±90min)
# * **🔄 Temporary files:** files you uploaded will disappear if Colab times out, closes or disconnects.
# * **🌐 Online only:** classic local editors can work offline.
# * **🗂️ Not ideal for big projects:** no folder structure.
# * **⚙️ Not 100% automated & compatible:** Some Python libraries need extra steps or don’t work well in Colab

# %% [markdown]
# ---

# %% [markdown]
# # 📝 Let’s Get Started!

# %% [markdown]
# *   Let's work with AI to create Python code to **remove the background** from an image.
# *   **Test your code on various images** with more or less complex backgrounds.

# %% [markdown]
# ---

# %% [markdown]
# # ✅ Step 1: Make Your Own Copy

# %% [markdown]
# Click the link below to create your own **editable notebook**.
# This ensures you can run and modify code freely.
# The original stays safe and unchanged.
#
# 👉 [**Click here to copy the notebook**](https://colab.research.google.com/drive/1qaFINJSUE7_vaGBkmFJ5niP8qoW8Do76?usp=copy)

# %% [markdown]
# ---

# %% [markdown]
# # 🖼️ Step 2: Upload an Image

# %% [markdown]
# Once you’re in your notebook copy:
# 	1.	Go to the `[]` on the code sample below.
# 	2.  Press ▶️ to run the code.
# 	3.	Choose an image file from your computer.
# 	4.	Your image will be stored temporarily in the session.
# 	5.	Click the **folder icon** 📁 on the left sidebar to verify it has been uploaded.
#
# 		👉 You will see a checkmark ✅ when the code has finished running.

# %%
from google.colab import files
uploaded = files.upload()

# This will prompt the user to upload local files (e.g., a CSV or image).
# Out:
#      <input type="file" id="files-676a3992-6de5-4c80-a0bb-a35ae80df3f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-676a3992-6de5-4c80-a0bb-a35ae80df3f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# # 🎨 Step 3: Code with Vibes

# %% [markdown]
# **🎨 Let’s Vibe Code!**
#
# Use Gemini (or ChatGPT) to help you write Python code that removes the background from your uploaded image.
#
# **🧠 How to prompt Gemini in Colab:**
#
# *   Click “generate” inside the code cell below
# *   Or find the Gemini icon ⭐️ in the top-right corner of your screen (next to the settings icon ⚙️ to chat directly).
#
# 👉 What can Gemini do?
# *   Gemini can write code, see your code and understand errors.
# *   It can copy code into a cell by using the + icon.
#
# **💡 Hint: Try this prompt:**
#
# 	Write a Python program to remove the background from an image file I just uploaded in Google Colab."

# %%
# Step 1: Install dependencies
# !pip install rembg onnxruntime

# Step 2: Import libraries
from rembg import remove
from PIL import Image
from google.colab import files
from IPython.display import display

# Step 3: Upload your image
uploaded = files.upload()

# Step 4: Remove background and save as PNG
for file_name in uploaded.keys():
    input_image = Image.open(file_name)
    output_image = remove(input_image)

    # Ensure we save with PNG format to preserve transparency
    output_path = f"no_bg_{file_name.rsplit('.', 1)[0]}.png"
    output_image.save(output_path, format="PNG")

    display(output_image)
    files.download(output_path)
# Out:
# ...
#      <input type="file" id="files-a65f43e5-417f-454f-9a88-c170ee3e39e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a65f43e5-417f-454f-9a88-c170ee3e39e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 🔍 Step 4: Check the result & Troubleshoot

# %% [markdown]
# **✅ Did it work?**
#
# *   Check the 🗂️ folder icon on the left toolbar.
# *   Do you find your image?
# *   Was the background removed?
#
# If your image appeared with the background removed — awesome!
# You’re vibing with code already.
#
#
# **👉 A note about Python libraries**
#
# *  Your program might be using a Python library for background removal called **rembg**.
# *  Usually, libraries need to be added with the command `pip install <library name>` in the terminal.
# *  In Google Colab, libraries can be **installed directly** from within the code itself.
# *  Gemini will generally **include** all the necessary libraries to the code it generates.
# *  Sometimes, Gemini might **forget to include dependencies** (libraries not explicitely used in the code, but necessary to other libraries).
#
#
# **❌ Didn’t work?**
#
# No worries.
# Even the best vibe coders hit speed bumps.
#
# 👉 Just **copy & paste the error message** into the AI (Gemini, ChatGPT, etc.) and say something like:
#
# > “It didn’t work. What to do?”
#
#
# **🧠 What might be going wrong?**
#
# *   You might be missing a **library**.
# *   The library might need a different **version**.
# *   It might depend on **another package** that’s not installed yet (some libraries require other libraries to be installed too).
#
# These are totally **normal issues** with code in general.

# %% [markdown]
# ---

# %% [markdown]
# # ✨ Going Beyond: Remix, Expand, Create

# %% [markdown]
# Once you’ve nailed it with one image, you can **level up your prompt** to:
# * 🌀 **Batch:** Process multiple images in a loop.
# * **🎛️ Power up:** Add tools like resize, crop, format conversion, or filters.
# * **🧠 Tool up:** Explore new libraries to expand your app further.
#
# Start small, remix, expand, and let your creativity lead the code.
